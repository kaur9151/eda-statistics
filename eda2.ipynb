# %%
import pandas as pd

# %%
data=pd.read_csv("https://raw.githubusercontent.com/kaur9151/eda-statistics/main/adult.data")

# %%
#data=data.to_csv()

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
data.shape
# Out:
# (32560, 15)

# %%
data.tail()
# Out:
#        39      State-gov   77516    Bachelors   13        Never-married  \
# 32555  27        Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40        Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58        Private  151910      HS-grad    9              Widowed
# 32558  22        Private  201490      HS-grad    9        Never-married
# 32559  52   Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical  Not-in-family   White     Male   2174   0   40  \
# 32555        Tech-support           Wife   White   Female      0   0   38
# 32556   Machine-op-inspct        Husband   White     Male      0   0   40
# 32557        Adm-clerical      Unmarried   White   Female      0   0   40
# 32558        Adm-clerical      Own-child   White     Male      0   0   20
# 32559     Exec-managerial           Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 32555   United-States   <=50K
# ...

# %%
header_list=['Age','Work_Class','Fnlwgt','Education','Education-num','Marital-Status','Occupation','Relationship','Race','Sex','Capital_Gain','Capital_loss','Hours-per-week','Native_country','Dominican_public']

# %%
data.to_csv("data2.csv", header=header_list, index=False)

# %%
data2=pd.read_csv("data2.csv")

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               32560 non-null  int64
#  1   Work_Class        32560 non-null  object
#  2   Fnlwgt            32560 non-null  int64
#  3   Education         32560 non-null  object
#  4   Education-num     32560 non-null  int64
#  5   Marital-Status    32560 non-null  object
#  6   Occupation        32560 non-null  object
#  7   Relationship      32560 non-null  object
#  8   Race              32560 non-null  object
#  9   Sex               32560 non-null  object
#  10  Capital_Gain      32560 non-null  int64
#  11  Capital_loss      32560 non-null  int64
#  12  Hours-per-week    32560 non-null  int64
#  13  Native_country    32560 non-null  object
#  14  Dominican_public  32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data2.head()
# Out:
#    Age         Work_Class  Fnlwgt   Education  Education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital-Status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_Gain  Capital_loss  Hours-per-week  Native_country Dominican_public
# ...

# %%
data2.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32560.0      38.581634      13.640642     17.0      28.0
# Fnlwgt          32560.0  189781.814373  105549.764924  12285.0  117831.5
# Education-num   32560.0      10.080590       2.572709      1.0       9.0
# Capital_Gain    32560.0    1077.615172    7385.402999      0.0       0.0
# Capital_loss    32560.0      87.306511     402.966116      0.0       0.0
# Hours-per-week  32560.0      40.437469      12.347618      1.0      40.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# Fnlwgt          178363.0  237054.5  1484705.0
# Education-num       10.0      12.0       16.0
# Capital_Gain         0.0       0.0    99999.0
# Capital_loss         0.0       0.0     4356.0
# Hours-per-week      40.0      45.0       99.0

# %%
data2[data2.duplicated()]
# Out:
#        Age         Work_Class  Fnlwgt      Education  Education-num  \
# 4880    25            Private  308144      Bachelors             13
# 5103    90            Private   52386   Some-college             10
# 9170    21            Private  250051   Some-college             10
# 11630   20            Private  107658   Some-college             10
# 13083   25            Private  195994        1st-4th              2
# 15058   21            Private  243368      Preschool              1
# 17039   46            Private  173243        HS-grad              9
# 18554   30            Private  144593        HS-grad              9
# 18697   19            Private   97261        HS-grad              9
# 21317   19            Private  138153   Some-college             10
# 21489   19            Private  146679   Some-college             10
# 21874   49            Private   31267        7th-8th              4
# 22299   25            Private  195994        1st-4th              2
# ...

# %%
data2.rename(columns = {'Dominican_public':'Annual_salary'}, inplace = True)

# %%
data2.head()
# Out:
#    Age         Work_Class  Fnlwgt   Education  Education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital-Status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_Gain  Capital_loss  Hours-per-week  Native_country Annual_salary
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Work_Class      32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education-num   32560 non-null  int64
#  5   Marital-Status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_Gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours-per-week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Annual_salary   32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data2_copy=data2.copy()

# %%
data2_copy.head()
# Out:
#    Age         Work_Class  Fnlwgt   Education  Education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital-Status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_Gain  Capital_loss  Hours-per-week  Native_country Annual_salary
# ...

# %%
data2_copy['Annual_salary']=data2_copy['Annual_salary'].str.replace('K','000')

# %%
data2_copy.head()
# Out:
#    Age         Work_Class  Fnlwgt   Education  Education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital-Status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_Gain  Capital_loss  Hours-per-week  Native_country Annual_salary
# ...

# %%
data2_copy['Annual_salary']=data2_copy['Annual_salary'].str.replace('<=','')

# %%
data2_copy['Annual_salary']=data2_copy['Annual_salary'].str.replace('>50000','55000')

# %%
data2_copy.head()
# Out:
#    Age         Work_Class  Fnlwgt   Education  Education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital-Status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_Gain  Capital_loss  Hours-per-week  Native_country Annual_salary
# ...

# %%
data2_copy.tail()
# Out:
#        Age     Work_Class  Fnlwgt    Education  Education-num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital-Status          Occupation Relationship    Race      Sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital_Gain  Capital_loss  Hours-per-week  Native_country  \
# ...

# %%
data2_copy['Annual_salary'].dtype
# Out:
# dtype('O')

# %%
data2_copy['Annual_salary']=data2_copy['Annual_salary'].astype('int')

# %%
data2_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Work_Class      32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education-num   32560 non-null  int64
#  5   Marital-Status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_Gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours-per-week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Annual_salary   32560 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 3.7+ MB

# %%
data2_copy.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32560.0      38.581634      13.640642     17.0      28.0
# Fnlwgt          32560.0  189781.814373  105549.764924  12285.0  117831.5
# Education-num   32560.0      10.080590       2.572709      1.0       9.0
# Capital_Gain    32560.0    1077.615172    7385.402999      0.0       0.0
# Capital_loss    32560.0      87.306511     402.966116      0.0       0.0
# Hours-per-week  32560.0      40.437469      12.347618      1.0      40.0
# Annual_salary   32560.0   51204.084767    2137.929860  50000.0   50000.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# Fnlwgt          178363.0  237054.5  1484705.0
# Education-num       10.0      12.0       16.0
# Capital_Gain         0.0       0.0    99999.0
# Capital_loss         0.0       0.0     4356.0
# Hours-per-week      40.0      45.0       99.0
# Annual_salary    50000.0   50000.0    55000.0

# %%
data2_copy.head()
# Out:
#    Age         Work_Class  Fnlwgt   Education  Education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital-Status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_Gain  Capital_loss  Hours-per-week  Native_country  Annual_salary
# ...

# %%
data2_copy['Work_Class'].unique()
# Out:
# array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
data2_copy['Work_Class']=data2_copy['Work_Class'].str.replace('?','NaN')
# Out:
# /tmp/ipykernel_77/3021119717.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data2_copy['Work_Class']=data2_copy['Work_Class'].str.replace('?','NaN')

# %%
data2_copy['Work_Class'].unique()
# Out:
# array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#        ' Local-gov', ' NaN', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
data2_copy[data2_copy['Fnlwgt'].notnull()]
# Out:
#        Age         Work_Class  Fnlwgt    Education  Education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital-Status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data2_copy['Education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
data2_copy['Education-num'].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8])

# %%
data2_copy['Marital-Status'].unique()
# Out:
# array([' Married-civ-spouse', ' Divorced', ' Married-spouse-absent',
#        ' Never-married', ' Separated', ' Married-AF-spouse', ' Widowed'],
#       dtype=object)

# %%
data2_copy['Occupation'].unique()
# Out:
# array([' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty',
#        ' Other-service', ' Adm-clerical', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
data2_copy['Occupation']=data2_copy['Occupation'].str.replace('?','NaN')
# Out:
# /tmp/ipykernel_77/3010087898.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data2_copy['Occupation']=data2_copy['Occupation'].str.replace('?','NaN')

# %%
data2_copy['Occupation'].unique()
# Out:
# array([' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty',
#        ' Other-service', ' Adm-clerical', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' NaN', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
data2_copy['Race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
data2_copy['Sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
data2_copy['Hours-per-week'].unique()
# Out:
# array([13, 40, 16, 45, 50, 80, 30, 35, 60, 20, 52, 44, 15, 25, 38, 43, 55,
#        48, 58, 32, 70,  2, 22, 56, 41, 28, 36, 24, 46, 42, 12, 65,  1, 10,
#        34, 75, 98, 33, 54,  8,  6, 64, 19, 18, 72,  5,  9, 47, 37, 21, 26,
#        14,  4, 59,  7, 99, 53, 39, 62, 57, 78, 90, 66, 11, 49, 84,  3, 17,
#        68, 27, 85, 31, 51, 77, 63, 23, 87, 88, 73, 89, 97, 94, 29, 96, 67,
#        82, 86, 91, 81, 76, 92, 61, 74, 95])

# %%
data2_copy['Native_country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
data2_copy['Native_country']=data2_copy['Native_country'].str.replace('?','NaN')
# Out:
# /tmp/ipykernel_77/1674808857.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data2_copy['Native_country']=data2_copy['Native_country'].str.replace('?','NaN')

# %%
data2_copy['Native_country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' NaN', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
data2_copy['Annual_salary'].unique()
# Out:
# array([50000, 55000])

# %%
data2_copy.to_csv('Clean_adult_data',index=False)

# %%
pd.read_csv('Clean_adult_data')
# Out:
#        Age         Work_Class  Fnlwgt    Education  Education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital-Status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data2_copy[data2_copy.duplicated()]
# Out:
#        Age         Work_Class  Fnlwgt      Education  Education-num  \
# 4880    25            Private  308144      Bachelors             13
# 5103    90            Private   52386   Some-college             10
# 9170    21            Private  250051   Some-college             10
# 11630   20            Private  107658   Some-college             10
# 13083   25            Private  195994        1st-4th              2
# 15058   21            Private  243368      Preschool              1
# 17039   46            Private  173243        HS-grad              9
# 18554   30            Private  144593        HS-grad              9
# 18697   19            Private   97261        HS-grad              9
# 21317   19            Private  138153   Some-college             10
# 21489   19            Private  146679   Some-college             10
# 21874   49            Private   31267        7th-8th              4
# 22299   25            Private  195994        1st-4th              2
# ...

# %%
categorical_features = [feature for feature in data2_copy.columns if data2_copy[feature].dtype == 'O']

# %%
numerical_features = [feature for feature in data2_copy.columns if data2_copy[feature].dtype != 'O']

# %%
data2_copy[numerical_features]
# Out:
#        Age  Fnlwgt  Education-num  Capital_Gain  Capital_loss  Hours-per-week  \
# 0       50   83311             13             0             0              13
# 1       38  215646              9             0             0              40
# 2       53  234721              7             0             0              40
# 3       28  338409             13             0             0              40
# 4       37  284582             14             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32555   27  257302             12             0             0              38
# 32556   40  154374              9             0             0              40
# 32557   58  151910              9             0             0              40
# 32558   22  201490              9             0             0              20
# 32559   52  287927              9         15024             0              40
#
#        Annual_salary
# ...

# %%
data2_copy[categorical_features]
# Out:
#               Work_Class    Education       Marital-Status  \
# 0       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 1                Private      HS-grad             Divorced
# 2                Private         11th   Married-civ-spouse
# 3                Private    Bachelors   Married-civ-spouse
# 4                Private      Masters   Married-civ-spouse
# ...                  ...          ...                  ...
# 32555            Private   Assoc-acdm   Married-civ-spouse
# 32556            Private      HS-grad   Married-civ-spouse
# 32557            Private      HS-grad              Widowed
# 32558            Private      HS-grad        Never-married
# 32559       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                Occupation    Relationship    Race      Sex  Native_country
# 0         Exec-managerial         Husband   White     Male   United-States
# 1       Handlers-cleaners   Not-in-family   White     Male   United-States
# ...

# %%
for col in categorical_features:
    print(f"{col}:{data2_copy[col].value_counts(normalize=True)*100}")
    print("*********************************************")
# Out:
# Work_Class: Private             69.705160
#  Self-emp-not-inc     7.804054
#  Local-gov            6.428133
#  NaN                  5.638821
#  State-gov            3.983415
#  Self-emp-inc         3.427518
#  Federal-gov          2.948403
#  Without-pay          0.042998
#  Never-worked         0.021499
# Name: Work_Class, dtype: float64
# *********************************************
# Education: HS-grad         32.251229
#  Some-college    22.392506
#  Bachelors       16.443489
#  Masters          5.291769
#  Assoc-voc        4.244472
#  11th             3.608722
#  Assoc-acdm       3.277027
#  10th             2.865479
#  7th-8th          1.984029
#  Prof-school      1.769042
#  9th              1.578624
#  12th             1.329853
#  Doctorate        1.268428
#  5th-6th          1.022727
#  1st-4th          0.515971
#  Preschool        0.156634
# Name: Education, dtype: float64
# *********************************************
# Marital-Status: Married-civ-spouse       45.995086
# ...

# %%
sns.countplot(x=data2_copy['Sex'])
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='count'>

# %%
import pandas as pd
import numpy as npport
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
sns.countplot(x=data2_copy['Work_Class'])
# Out:
# <AxesSubplot: xlabel='Work_Class', ylabel='count'>

# %%
sns.kdeplot(data2_copy['Hours-per-week'])
data2_copy.head()
# Out:
#    Age         Work_Class  Fnlwgt   Education  Education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital-Status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_Gain  Capital_loss  Hours-per-week  Native_country  Annual_salary
# ...

# %%
sns.kdeplot(data2_copy['Age'])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data2_copy['Education-num'])
# Out:
# <AxesSubplot: xlabel='Education-num', ylabel='Density'>

# %%
data2_copy.head()
# Out:
#    Age         Work_Class  Fnlwgt   Education  Education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital-Status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_Gain  Capital_loss  Hours-per-week  Native_country  Annual_salary
# ...

# %%
data2_copy['Work_Class'].value_counts().plot.pie(y=data2_copy["Work_Class"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='Work_Class'>

# %%
data2_copy['Education'].value_counts().plot.pie(y=data2_copy["Education"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='Education'>
